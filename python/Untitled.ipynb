# %%
import pandas as pd

# %%
collection_url = "https://github.com/alexamies/chinesenotes.com/blob/master/data/corpus/collections.csv"
collections = pd.read_table(collection_url, sep="\t", skiprows=(0,1))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-c1658729c8c6> in <module>()
#       1 collection_url = "https://github.com/alexamies/chinesenotes.com/blob/master/data/corpus/collections.csv"
# ----> 2 collections = pd.read_table(collection_url, sep="\t", skiprows=(0,1))
#
# ...
